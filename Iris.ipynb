# %% [markdown]
# <a href="https://colab.research.google.com/github/Sushant072003/Datascience_internship/blob/main/Iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IRIS FLOWER CLASSIFICATION  :
#
# Name : Sushant Yadav
# Domain : Data Science
#
# Aim : To Develop a Model that can classify iris flowers into differrent species based on their sepal and petal measurment.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("/content/drive/MyDrive/Python_dataset/IRIS.csv")
df = pd.DataFrame(data)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
df.tail(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 141           6.9          3.1           5.1          2.3  Iris-virginica
# 142           5.8          2.7           5.1          1.9  Iris-virginica
# 143           6.8          3.2           5.9          2.3  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df.loc[df['species'] == 'Iris-setosa', 'species'] = 0
df.loc[df['species'] == 'Iris-versicolor', 'species'] = 1
df.loc[df['species'] == 'Iris-virginica', 'species'] = 2

df['species'] = df['species'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width     species
# count    150.000000   150.000000    150.000000   150.000000  150.000000
# mean       5.843333     3.054000      3.758667     1.198667    1.000000
# std        0.828066     0.433594      1.764420     0.763161    0.819232
# min        4.300000     2.000000      1.000000     0.100000    0.000000
# 25%        5.100000     2.800000      1.600000     0.300000    0.000000
# 50%        5.800000     3.000000      4.350000     1.300000    1.000000
# 75%        6.400000     3.300000      5.100000     1.800000    2.000000
# max        7.900000     4.400000      6.900000     2.500000    2.000000

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 3

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (147, 5)

# %% [markdown]
# # Data Vistualizing :

# %%
# Create a bar plot to see the count of species category
sns.countplot(data = df , x = 'species' )
plt.show()

# %%
sns.histplot(data=df,x='sepal_length',color="grey" , kde=True)
plt.show()

# %%
sns.histplot(data=df,x='sepal_width',color="lightgreen" ,kde=True)
plt.show()

# %%
sns.histplot(data=df,x='petal_length',color="grey" , kde=True)
plt.show()

# %%
sns.histplot(data=df,x='petal_width',color="lightgreen",kde=True)
plt.show()

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# # Model Training :

# %%
x = df[["sepal_length","sepal_width","petal_length","petal_width"]]
y = df["species"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
Model = LogisticRegression()
Model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
# Evaluating the model to verify the accuray

print("Accuracy : ",Model.score(x_test,y_test)*100)
print("Accuracy : ",Model.score(x_train,y_train)*100)
# Out:
# Accuracy :  100.0
# Accuracy :  95.72649572649573

# %%
from sklearn.neighbors import KNeighborsClassifier

# Building machine learning model and training them
Model2 = KNeighborsClassifier()
Model2.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
# Evaluating the model to verify the accuray

print("Accuracy : ",Model2.score(x_test,y_test)*100)
print("Accuracy : ",Model2.score(x_train,y_train)*100)
# Out:
# Accuracy :  100.0
# Accuracy :  95.72649572649573

# %% [markdown]
# # Model Testing :

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
# For testing we create a new dataframe

data = pd.DataFrame({'sepal_length': [3] , 'sepal_width': [4] , 'petal_length': [0.7] , 'petal_width': [0.4]})
print(data)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0             3            4           0.7          0.4

# %%
# Make prediction
Prediction = Model2.predict(data)
print(Prediction)
# Out:
# [0]
